# %%
# !pip install litellm
# Out:
# ...
#   Obtaining dependency information for litellm from https://files.pythonhosted.org/packages/e6/f6/6aeedf8c6e75bfca08b9c73385186016446e8286803b381fcb9cac9c1594/litellm-1.78.5-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      -------------------------------------- - 41.0/42.9 kB ? eta -:--:--
#      -------------------------------------- 42.9/42.9 kB 695.3 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for aiohttp>=3.10 from https://files.pythonhosted.org/packages/0e/e3/4481f50dd6f27e9e58c19a60cff44029641640237e35d32b04aaee8cf95f/aiohttp-3.13.1-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for fastuuid>=0.13.0 from https://files.pythonhosted.org/packages/f4/0c/f970a4222773b248931819f8940800b760283216ca3dda173ed027e94bdd/fastuuid-0.13.5-cp312-cp312-win_amd64.whl.metadata
# ...

# %%
import os
from dotenv import load_dotenv
load_dotenv()

secret = os.environ.get('GEMINI_API_KEY')
print('secret')
# Out:
# secret

# %%
print('hello world')
# Out:
# hello world
